# %% [markdown]
# <a href="https://colab.research.google.com/github/VimukthiRandika1997/Computer-Vision/blob/dev/Diffusers/InstantDrag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SNU-VGILab/InstantDrag.git
# !cd InstantDrag
# Out:
# Cloning into 'InstantDrag'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 47 (delta 7), reused 39 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 6.02 MiB | 3.51 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !pip install transformers==4.44.2 diffusers==0.30.1 accelerate==0.33.0 gradio==4.44.0 opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# Set share=True in run_demo.py
# !ls
# %cd ./InstantDrag/demo/
# !CUDA_VISIBLE_DEVICES=0
# !python run_demo.py
# Out:
# InstantDrag  sample_data
# /content/InstantDrag/demo
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 10.2MB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:02,  5.86it/s]
# README.md: 100% 36.0/36.0 [00:00<00:00, 391kB/s]
#
# (…)iffusion/scheduler/scheduler_config.json: 100% 807/807 [00:00<00:00, 6.87MB/s]
#
# flowdiffusion/model_index.json: 100% 516/516 [00:00<00:00, 4.93MB/s]
#
# (…)ature_extractor/preprocessor_config.json: 100% 780/780 [00:00<00:00, 6.73MB/s]
#
# flowdiffusion/safety_checker/config.json: 100% 792/792 [00:00<00:00, 8.37MB/s]
#
# flowdiffusion/unet/config.json: 100% 1.88k/1.88k [00:00<00:00, 17.6MB/s]
#
# flowdiffusion/vae/config.json: 100% 817/817 [00:00<00:00, 8.74MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
#
# model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
# ...
