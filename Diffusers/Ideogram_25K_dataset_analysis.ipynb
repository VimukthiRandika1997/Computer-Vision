# %% [markdown]
# <a href="https://colab.research.google.com/github/VimukthiRandika1997/Computer-Vision/blob/dev/Diffusers/Ideogram_25K_dataset_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install datasets diffusers transformers

# %%
from datasets import load_dataset

# Use the `streaming=True` argument to load the dataset in streaming mode.
# This allows you to start using the data without waiting for the entire download.
dataset = load_dataset("terminusresearch/ideogram-25k", data_dir="v1", streaming=True)
# Out:
# Resolving data files:   0%|          | 0/19 [00:00<?, ?it/s]

# %%
i = 0
img_list = []
for img in dataset["train"]:
  print(img)
  print(type(img["png"]))
  img_list.append(img["png"])
  i += 1
  if i == 10:
    break
# Out:
# {'__key__': 'ideogram-hashed/87a1d72901ff43b0e24dde4c814302c48a067594309b862614499432cef584ec', '__url__': 'hf://datasets/terminusresearch/ideogram-25k@38bfee0c397db20a44e2930aa1f3187caa1fe2b0/v1/ideogram-25k_0000.tar', 'png': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7C0898F0B820>}
# <class 'PIL.PngImagePlugin.PngImageFile'>
# {'__key__': 'ideogram-hashed/ee7a0d7127294340e274c5fe6bb21d2a227559570869ba5a57efd582e0a36af8', '__url__': 'hf://datasets/terminusresearch/ideogram-25k@38bfee0c397db20a44e2930aa1f3187caa1fe2b0/v1/ideogram-25k_0000.tar', 'png': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=720x1280 at 0x7C0898886650>}
# <class 'PIL.PngImagePlugin.PngImageFile'>
# ...

# %%
img_list[1]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=720x1280>
