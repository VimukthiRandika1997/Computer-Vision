# %% [markdown]
# <a href="https://colab.research.google.com/github/VimukthiRandika1997/Computer-Vision/blob/dev/Miniconda_hack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install miniconda
# !mkdir -p ~/miniconda3
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
# !bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# !rm -rf ~/miniconda3/miniconda.sh
!~/miniconda3/bin/conda init bash
# !bash
# Out:
# Streaming output truncated to the last 5000 lines.
# CondaVerificationError: The package for pytorch located at /root/miniconda3/pkgs/pytorch-1.12.1-py3.10_cuda11.3_cudnn8.3.2_0
# appears to be corrupted. The path 'lib/python3.10/site-packages/torch/include/caffe2/utils/signal_handler.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at /root/miniconda3/pkgs/pytorch-1.12.1-py3.10_cuda11.3_cudnn8.3.2_0
# appears to be corrupted. The path 'lib/python3.10/site-packages/torch/include/caffe2/utils/simple_queue.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for pytorch located at /root/miniconda3/pkgs/pytorch-1.12.1-py3.10_cuda11.3_cudnn8.3.2_0
# appears to be corrupted. The path 'lib/python3.10/site-packages/torch/include/caffe2/utils/smart_tensor_printer.h'
# specified in the package manifest cannot be found.
#
# ...

# %%
conda env create -f environment.yaml
